# %% [markdown]
# ## Clean up terrorism data

# %%
# Dependencies and Setup
import pandas as pd
import json
import numpy as np

# %%
# Read csv file and convert to dataframe
terrorism_file = "files/globalterrorismd.csv"

terrorism_df = pd.read_csv(terrorism_file)
terrorism_df
# Out:
#         year         country                      region              state  \
# 0       1990         Lebanon  Middle East & North Africa             Beirut
# 1       1990           India                  South Asia  Jammu and Kashmir
# 2       1990           India                  South Asia  Jammu and Kashmir
# 3       1990           India                  South Asia  Jammu and Kashmir
# 4       1990         Bolivia               South America         Cochabamba
# ...      ...             ...                         ...                ...
# 150387  2018     Afghanistan                  South Asia              Zabul
# 150388  2018     Afghanistan                  South Asia             Faryab
# 150389  2018     Afghanistan                  South Asia            Jawzjan
# 150390  2018     Afghanistan                  South Asia            Helmand
# 150391  2018  United Kingdom              Western Europe   Northern Ireland
#
#                              city   latitude  longitude       nationality
# 0                          Beirut  33.888523  35.503513           Lebanon
# 1                        Srinagar  34.083740  74.789902             India
# 2                        Srinagar  34.083740  74.789902             India
# 3                        Srinagar  34.083740  74.789902             India
# 4                      Cochabamba -17.382789 -66.166439     United States
# ...                           ...        ...        ...               ...
# 150387                Sorkhi Sang  32.445646  66.876249       Afghanistan
# 150388  Khwaja Sabz Posh district  36.057119  64.845477       Afghanistan
# 150389                    Dik Sar  36.229290  65.460288       Afghanistan
# 150390           Nad Ali district  31.639085  64.243436       Afghanistan
# 150391                    Belfast  54.607711  -5.956210  Northern Ireland
#
# [150392 rows x 8 columns]

# %%
# Use count function to get the number of attacks each year per country
group_country = terrorism_df.groupby(["country", "year"])["country"].count()
group_country
# Out:
# country      year
# Afghanistan  1990     2
#              1991    30
#              1992    36
#              1994     9
#              1995     6
#                      ..
# Zimbabwe     2011     1
#              2013     3
#              2014     1
#              2017     3
#              2018     2
# Name: country, Length: 2650, dtype: int64

# %%
# convert above results to a dataframe
new_data = pd.DataFrame(group_country).rename(columns={"country": "attacksCount"}).reset_index()
new_data
# Out:
#           country  year  attacksCount
# 0     Afghanistan  1990             2
# 1     Afghanistan  1991            30
# 2     Afghanistan  1992            36
# 3     Afghanistan  1994             9
# 4     Afghanistan  1995             6
# ...           ...   ...           ...
# 2645     Zimbabwe  2011             1
# 2646     Zimbabwe  2013             3
# 2647     Zimbabwe  2014             1
# 2648     Zimbabwe  2017             3
# 2649     Zimbabwe  2018             2
#
# [2650 rows x 3 columns]

# %%
# save file to json format
terrorism_count = new_data.to_json("files/terrorismAttacks.json", orient="records")

# %%
# extract country of attack and attacker nationality
comparison = terrorism_df[["country", "nationality"]] 
comparison
# Out:
#                country       nationality
# 0              Lebanon           Lebanon
# 1                India             India
# 2                India             India
# 3                India             India
# 4              Bolivia     United States
# ...                ...               ...
# 150387     Afghanistan       Afghanistan
# 150388     Afghanistan       Afghanistan
# 150389     Afghanistan       Afghanistan
# 150390     Afghanistan       Afghanistan
# 150391  United Kingdom  Northern Ireland
#
# [150392 rows x 2 columns]

# %%
# use numpy to compare country and nationality to check number of domestic attacks vs international
comparison_column = np.where(comparison["country"] == comparison["nationality"], True, False)
# compare "country"` and `"nationality"`

print(comparison_column)
# Out:
# [ True  True  True ...  True  True False]

# %%
comparison["equal"] = comparison_column
print(comparison)
# Out:
#                country       nationality  equal
# 0              Lebanon           Lebanon   True
# 1                India             India   True
# 2                India             India   True
# 3                India             India   True
# 4              Bolivia     United States  False
# ...                ...               ...    ...
# 150387     Afghanistan       Afghanistan   True
# 150388     Afghanistan       Afghanistan   True
# 150389     Afghanistan       Afghanistan   True
# 150390     Afghanistan       Afghanistan   True
# 150391  United Kingdom  Northern Ireland  False
#
# [150392 rows x 3 columns]
# /Users/jessicaramosmolina/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
comparison_data = pd.DataFrame(comparison)
comparison_data
# Out:
#                country       nationality  equal
# 0              Lebanon           Lebanon   True
# 1                India             India   True
# 2                India             India   True
# 3                India             India   True
# 4              Bolivia     United States  False
# ...                ...               ...    ...
# 150387     Afghanistan       Afghanistan   True
# 150388     Afghanistan       Afghanistan   True
# 150389     Afghanistan       Afghanistan   True
# 150390     Afghanistan       Afghanistan   True
# 150391  United Kingdom  Northern Ireland  False
#
# [150392 rows x 3 columns]

# %%
count2 = comparison_data.groupby(["country", "nationality", "equal"])["equal"].count()
count2
# Out:
# country      nationality    equal
# Afghanistan  Afghanistan    True     12408
#              Algeria        False        2
#              Asian          False        3
#              Australia      False        3
#              Bangladesh     False        6
#                                      ...
# Zimbabwe     Ethiopia       False        1
#              Great Britain  False        3
#              South Africa   False        1
#              United States  False        1
#              Zimbabwe       True        35
# Name: equal, Length: 1916, dtype: int64

# %%
new_count = pd.DataFrame(count2).rename(columns={"equal":"xyz"}).reset_index()
new_count.head(50)
# Out:
#         country           nationality  equal    xyz
# 0   Afghanistan           Afghanistan   True  12408
# 1   Afghanistan               Algeria  False      2
# 2   Afghanistan                 Asian  False      3
# 3   Afghanistan             Australia  False      3
# 4   Afghanistan            Bangladesh  False      6
# 5   Afghanistan                Canada  False      7
# 6   Afghanistan                 China  False      4
# 7   Afghanistan               Denmark  False      1
# 8   Afghanistan            East Timor  False      1
# 9   Afghanistan                France  False     12
# 10  Afghanistan               Georgia  False      1
# 11  Afghanistan               Germany  False     14
# 12  Afghanistan         Great Britain  False     12
# 13  Afghanistan               Iceland  False      1
# 14  Afghanistan                 India  False     28
# 15  Afghanistan         International  False    903
# 16  Afghanistan                  Iran  False     10
# 17  Afghanistan                  Iraq  False      9
# 18  Afghanistan                Israel  False      1
# 19  Afghanistan                 Italy  False     11
# 20  Afghanistan                 Japan  False      5
# 21  Afghanistan         Multinational  False     37
# 22  Afghanistan                 Nepal  False      1
# 23  Afghanistan           Netherlands  False      3
# 24  Afghanistan                Norway  False      1
# 25  Afghanistan              Pakistan  False     37
# 26  Afghanistan                Russia  False      2
# 27  Afghanistan          Saudi Arabia  False      1
# 28  Afghanistan           South Korea  False      6
# 29  Afghanistan                 Spain  False      1
# 30  Afghanistan                Sweden  False      2
# 31  Afghanistan           Switzerland  False      2
# 32  Afghanistan            Tajikistan  False      2
# 33  Afghanistan              Thailand  False      1
# 34  Afghanistan                Turkey  False     18
# 35  Afghanistan          Turkmenistan  False      1
# 36  Afghanistan               Ukraine  False      2
# 37  Afghanistan  United Arab Emirates  False      1
# 38  Afghanistan         United States  False     86
# 39      Albania               Albania   True     69
# 40      Albania                  Cuba  False      1
# 41      Albania                Greece  False      1
# 42      Albania                 Italy  False      1
# 43      Albania           Netherlands  False      1
# 44      Albania         United States  False      2
# 45      Algeria           Afghanistan  False      3
# 46      Algeria               Albania  False      5
# 47      Algeria               Algeria   True   2622
# 48      Algeria                Angola  False      1
# 49      Algeria    Bosnia-Herzegovina  False      1

# %%
# new_count.columns
new_df = new_count[["country", "equal", "xyz"]]
new_df.head()
# Out:
#        country  equal    xyz
# 0  Afghanistan   True  12408
# 1  Afghanistan  False      2
# 2  Afghanistan  False      3
# 3  Afghanistan  False      3
# 4  Afghanistan  False      6

# %%
equal_country = new_df.groupby(["country", "equal"])["xyz"].sum()
equal_country
# Out:
# country      equal
# Afghanistan  False     1238
#              True     12408
# Albania      False        6
#              True        69
# Algeria      False       91
#                       ...
# Zaire        True        25
# Zambia       False        2
#              True        25
# Zimbabwe     False        7
#              True        35
# Name: xyz, Length: 359, dtype: int64

# %%
new_df2 = pd.DataFrame(equal_country).reset_index()
new_df2.head(50)
# Out:
#                 country  equal    xyz
# 0           Afghanistan  False   1238
# 1           Afghanistan   True  12408
# 2               Albania  False      6
# 3               Albania   True     69
# 4               Algeria  False     91
# 5               Algeria   True   2622
# 6                Angola  False     59
# 7                Angola   True    373
# 8   Antigua and Barbuda   True      1
# 9             Argentina  False     28
# 10            Argentina   True    161
# 11              Armenia  False      6
# 12              Armenia   True     19
# 13            Australia  False     12
# 14            Australia   True     74
# 15              Austria  False     19
# 16              Austria   True     33
# 17           Azerbaijan  False      6
# 18           Azerbaijan   True     44
# 19              Bahamas  False      1
# 20              Bahamas   True      2
# 21              Bahrain  False     16
# 22              Bahrain   True    189
# 23           Bangladesh  False     23
# 24           Bangladesh   True   1554
# 25             Barbados   True      1
# 26              Belarus  False      2
# 27              Belarus   True     11
# 28              Belgium  False     23
# 29              Belgium   True     35
# 30               Belize  False      5
# 31               Belize   True      2
# 32                Benin   True      7
# 33               Bhutan   True      6
# 34              Bolivia  False     14
# 35              Bolivia   True     89
# 36   Bosnia-Herzegovina  False     54
# 37   Bosnia-Herzegovina   True    103
# 38             Botswana   True      2
# 39               Brazil  False     31
# 40               Brazil   True    161
# 41               Brunei   True      1
# 42             Bulgaria  False      6
# 43             Bulgaria   True     44
# 44         Burkina Faso  False      4
# 45         Burkina Faso   True    117
# 46              Burundi  False     33
# 47              Burundi   True    588
# 48             Cambodia  False     51
# 49             Cambodia   True    201

# %%
comparison_df = new_df2.to_json("files/comparisondata.json", orient="records")

# %%
country_list = new_data.country.unique()
country_list
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia-Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Czechoslovakia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'East Germany (GDR)',
#        'East Timor', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guadeloupe',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'International', 'Iran', 'Iraq', 'Ireland', 'Israel',
#        'Italy', 'Ivory Coast', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia',
#        'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Lithuania',
#        'Luxembourg', 'Macau', 'Macedonia', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Martinique',
#        'Mauritania', 'Mexico', 'Moldova', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'North Korea', 'Norway', 'Pakistan', 'Panama', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar',
#        'Republic of the Congo', 'Romania', 'Russia', 'Rwanda',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Serbia-Montenegro',
#        'Sierra Leone', 'Singapore', 'Slovak Republic', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Korea',
#        'South Sudan', 'Soviet Union', 'Spain', 'Sri Lanka',
#        'St. Kitts and Nevis', 'St. Lucia', 'Sudan', 'Suriname',
#        'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'West Bank and Gaza Strip',
#        'West Germany (FRG)', 'Western Sahara', 'Yemen', 'Yugoslavia',
#        'Zaire', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
list_df = pd.DataFrame(country_list, columns=["country_names"])
list_df
# Out:
#            country_names
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                 Angola
# 4    Antigua and Barbuda
# ..                   ...
# 188                Yemen
# 189           Yugoslavia
# 190                Zaire
# 191               Zambia
# 192             Zimbabwe
#
# [193 rows x 1 columns]

# %%
countryList = list_df.to_json("files/countryList.json", orient="records")
